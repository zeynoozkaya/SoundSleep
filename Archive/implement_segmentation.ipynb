# %% [markdown]
# ## Script for Testing Segmentation CNN

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import accuracy_score, f1_score
from matplotlib import pyplot as plt
from scipy.signal import resample_poly
from math import gcd
import pickle
import random
from scipy.ndimage import uniform_filter1d

from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Input, UpSampling1D, Concatenate,Dropout
from tensorflow.keras.models import Model

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ## Loading in Data

# %%
features_all = pd.read_pickle("training_features_18042026.pkl")
features_all_temp = features_all
features_all = features_all[~((features_all["Subject"] == "RL03JG") & (features_all["Nap Number"] == 5))] # presentation for this subject is 0 ? somethign weird 

labels = pd.read_pickle("segments.pkl")

print("==========SANITY CHECK==========")
print("Nap IDs align? ", (labels["Nap_ID"].values == features_all["Nap Number"].values).all())
print("Subject rows align? ", (labels["Subject"].values == features_all["Subject"].values).all())
# Out:
# ==========SANITY CHECK==========
# Nap IDs align?  True
# Subject rows align?  True

# %%
# concatenate dfs
features_all = features_all.reset_index(drop=True)
labels = labels.reset_index(drop=True)

features_all = pd.concat([features_all, labels], axis=1)

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Pre-processing functions

# %%
# for one neuron segmentation converts output to binary based on threshold 
def convert_to_binary(y_pred_test,thr=.5):
    y_pred_test_thr = []
    for input in y_pred_test:
        arr = np.zeros(len(input))
        #print(np.shape(input))
        for k in range(np.shape(input)[0]):
            if input[k] >= thr:
                arr[k] = 1 
            else:
                arr[k] = 0
        y_pred_test_thr.append(arr)
    return y_pred_test_thr

# %%
def to_one_hot(y, num_classes=2):
    """
    Convert binary labels to one-hot encoding.
    Input:  (samples, timesteps, 1)  — values 0 or 1
    Output: (samples, timesteps, num_classes)
    """
    y_squeezed = y[..., 0].astype(int)          # (14280, 2248)
    return np.eye(num_classes)[y_squeezed]

# %%
def iou_metric(y_true, y_pred, threshold=0.5):
    y_pred_bin = (y_pred > threshold).astype(int)
    intersection = np.logical_and(y_true, y_pred_bin).sum()
    union = np.logical_or(y_true, y_pred_bin).sum()
    return intersection / union

# %%
def weighted_bce(y_true, y_pred):
    global pos_weight
    return tf.keras.losses.binary_crossentropy(y_true, y_pred) * (
        y_true * pos_weight + (1 - y_true)
    )

# %%
# function for resampling time series data to sampling frequency of epochs 
def resample_timeseries(X, orig_fs, target_fs):

    g = gcd(orig_fs, target_fs)
    up   = target_fs // g   # upsample factor
    down = orig_fs   // g   # downsample factor

    resampled = resample_poly(X, up, down, axis=-1)

    # fix weirdness caused by resampling 
    resampled = (resampled >= 0.5).astype(int)[0:len(resampled)] 
    
    return resampled

# %%
def plot_random_epoch(df,random=True,subject=None,epoch=None,nap_id=None):
    """
    Randomly selects a Subject, Nap_ID, and epoch and plots:
    - Zygo + Contractions Zygo (subplot 1)
    - Corr + Contractions Corr (subplot 2)
    """

    # Random selection
    if random: 
        subject_list = df.loc[:, ~df.columns.duplicated()]
        subject = np.random.choice(subject_list["Subject"].unique())

        
        nap_id   = np.random.choice(sub_df["Nap Number"].unique())
        epoch    = np.random.randint(0, 60)
    else:
        subject = subject 
        epoch = epoch -1
        nap_id = nap_id 
    
    
    sub_df  = df[df.iloc[:, 0] == subject]  
    nap_df   = sub_df[sub_df["Nap_ID"] == nap_id]
    # Extract the signals for that epoch
    zygo             = nap_df["Zygo"].values[epoch][:-1]
    zygo_cont        = nap_df["Contraction Zygo"].values[epoch][:-1]
    corr             = nap_df["Corr"].values[epoch][:-1]
    corr_cont        = nap_df["Contraction Corr"].values[epoch][:-1]

    # Plot
    fig, axes = plt.subplots(2, 1, figsize=(12, 6), sharex=True)
    fig.suptitle(f"Subject: {subject} | Nap: {nap_id} | Epoch: {epoch+1}", fontsize=13)

    axes[0].plot(zygo,      label="Zygo",             color="steelblue")
    axes[0].plot(zygo_cont*75, label="Contraction Zygo", color="tomato")
    axes[0].set_ylabel("Zygo")
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    axes[1].plot(corr,      label="Corr",             color="steelblue")
    axes[1].plot(corr_cont*75, label="Contraction Corr", color="tomato")
    axes[1].set_ylabel("Corr")
    axes[1].set_xlabel("sampels")
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# Usage

# %% [markdown]
# ### Convolution functions

# %%
def unet_1d(epoch_len, feature_num, num_classes):
    inputs = Input(shape=(epoch_len, feature_num))

    # Encoder
    e1 = Conv1D(32, kernel_size=3, padding='same', activation='relu',kernel_regularizer=l2(0.001))(inputs)
    e1 = Dropout(0.4)(e1)  # bump up from 0.3
    p1 = MaxPooling1D(pool_size=2)(e1)

    e2 = Conv1D(64, kernel_size=3, padding='same', activation='relu',
            kernel_regularizer=l2(0.001))(p1)
    e2 = Dropout(0.4)(e2)
    p2 = MaxPooling1D(pool_size=2)(e2)

    # Bottleneck
    b = Conv1D(128, kernel_size=3, padding='same', activation='relu')(p2)

    # Decoder
    u1 = UpSampling1D(size=2)(b)
    u1 = Concatenate()([u1, e2])
    d1 = Conv1D(64, kernel_size=3, padding='same', activation='relu')(u1)

    u2 = UpSampling1D(size=2)(d1)
    u2 = Concatenate()([u2, e1])
    d2 = Conv1D(32, kernel_size=3, padding='same', activation='relu')(u2)

    
    # Output
    # outputs = Conv1D(num_classes, kernel_size=1, activation='sigmoid')(d2) numclasses = 1 single output neuron 
    outputs = Conv1D(num_classes, kernel_size=1, activation='softmax')(d2) # numclasses = 2 two output neurons (contraction vs no contraction)

    # dense layer for output 
    
    return Model(inputs, outputs)

# %%
def run_kfold_training(model_func,X_train_full, X, y,  input_shape, num_classes, feature_num,compile_kwargs, fit_kwargs=None, # arguments fed to model.fit() 
                       n_splits=5,random_state=42, shuffle=True, verbose=1,epoch_num=10,
                         type=1,): # model type (1: single head count, 2: two head count and duration, 3: two head for zygo and corr, 4: four head) 
   # returns a dictionary with {"models", "histories", "cv_scores"}.     

    if fit_kwargs is None:
        fit_kwargs = {}
    fit_kwargs = fit_kwargs.copy()

 

    kf = KFold(n_splits=n_splits, random_state=random_state, shuffle=shuffle)
    models = []
    histories = []
    cv_scores = []

    fold = 1
    for train_idx, val_idx in kf.split(X_train_full):
        print(f"Fold: {fold} {'='*65}")
        # X_train, X_val = X[train_idx], X[val_idx]
        # y_train, y_val = y[train_idx], y[val_idx]
        X_train = np.array(X_train_full[train_idx], dtype=np.float32)
        X_val = np.array(X_train_full[val_idx], dtype=np.float32)
        y_train = np.array(y[train_idx], dtype=np.float32)
        y_val = np.array(y[val_idx], dtype=np.float32)

 
        model = model_func(input_shape, feature_num,num_classes)
        model.compile(**compile_kwargs)

  
        if type ==2:

            history = model.fit(
                    X_train,
                    {"count_output": y_train[:, 0],
                    "duration_output": y_train[:, 1],},
                        validation_data=(X_val,  {
                        "count_output": y_val[:, 0],
                        "duration_output": y_val[:, 1],
                    }
                    ),epochs=epoch_num,
                    verbose=verbose,
                )
            
            scores = model.evaluate(X_val, {
                                    "count_output": y_val[:, 0],
                                    "duration_output": y_val[:, 1],
                                    }, 
                                    return_dict=True)
            
        elif type == 3:
            history = model.fit(
                    X_train,
                    {"zygo_output": y_train[:, 0],
                    "corr_output": y_train[:, 1],},
                        validation_data=(X_val,  {
                        "zygo_output": y_val[:, 0],
                        "corr_output": y_val[:, 1],
                    }
                    ),epochs=epoch_num,
                    )
            
            scores = model.evaluate(X_val, {
            "zygo_output": y_val[:, 0],
            "corr_output": y_val[:, 1],
                },return_dict=True)
            
        elif type == 4:
              history = model.fit(X_train, {
                        'zygo_count_output': y_train[:, 0],
                        'zygo_duration_output': y_train[:, 1],
                        'corr_count_output': y_train[:, 2],
                        'corr_duration_output': y_train[:, 3]
                    }, epochs=epoch_num, validation_data=(
                    X_val,
                    {
                        'zygo_count_output': y_val[:, 0],
                        'zygo_duration_output': y_val[:, 1],
                        'corr_count_output': y_val[:, 2],
                        'corr_duration_output': y_val[:, 3]
                    }
                ),  
                )
              
              scores = model.evaluate(X_val,{
                'zygo_count_output': y_val[:, 0],
                'zygo_duration_output': y_val[:, 1],
                'corr_count_output': y_val[:, 2],
                'corr_duration_output': y_val[:, 3]
            }, verbose=0, return_dict=True)            

        else:
            history = model.fit(
            X_train,
            y_train,
            validation_data=(X_val, y_val), epochs=epoch_num,
        )
            
            scores = model.evaluate(X_val, y_val, return_dict=True)

        

        fold += 1
        models.append(model)
        histories.append(history)
        cv_scores.append(scores)

    return {
        "models": models,
        "histories": histories,
        "cv_scores": cv_scores,
    }

# %% [markdown]
# ## Running Model

# %% [markdown]
# ### Defining Training Data

# %%
# resample labels to match the features 
features_all["Contraction Corr"] = features_all["Contraction Corr"].apply(
    lambda x: resample_timeseries(x, orig_fs=2080, target_fs=250)
)

features_all["Contraction Zygo"] = features_all["Contraction Zygo"].apply(
    lambda x: resample_timeseries(x, orig_fs=2080, target_fs=250)
)

# %%
# when splitting epochs later 
subject = pd.concat(
    [features_all_temp["Subject"],
     features_all_temp["Subject"]],
    ignore_index=True
)

nap = pd.concat(
    [features_all["Nap_ID"],
     features_all["Nap_ID"]],
    ignore_index=True
)

epoch = pd.concat(
    [features_all["Triggers_Order_Nap"],
     features_all["Triggers_Order_Nap"]],
    ignore_index=True
)

muscle_groups = pd.concat(
    [features_all["True_Muscle_Activated"],
     features_all["True_Muscle_Activated"]],
    ignore_index=True
)

X_zygo = features_all[["Zygo"]] 
X_corr = features_all[["Corr"]]

X_zygo = X_zygo.to_numpy()
X_zygo = np.array(X_zygo.tolist())
X_zygo = np.transpose(X_zygo, (0, 2, 1)) # setting dimensions 

X_corr = X_corr.to_numpy()
X_corr = np.array(X_corr.tolist())
X_corr = np.transpose(X_corr, (0, 2, 1)) # setting dimensions 

y_zygo = features_all[["Contraction Zygo"]].to_numpy()
y_corr = features_all[["Contraction Corr"]].to_numpy()

y_zygo = np.array(y_zygo.tolist())
y_corr = np.array(y_corr.tolist())


X = np.concatenate((X_zygo, X_corr), axis=0)
y = np.concatenate((y_zygo, y_corr), axis=0)      

indices = np.arange(len(X))
idx_train, idx_test, muscle_train, muscle_test,subj_train, subj_test,epoch_train, epoch_test,nap_train, nap_test = train_test_split(indices, 
                                                                                        muscle_groups,
                                                                                        subject,
                                                                                        epoch,
                                                                                        nap, test_size=0.2, random_state=42) # keep 20% purely for testing 

# split like this to be able to recover the indices for later when rescoring 
X_train_full = X[idx_train]
X_test = X[idx_test]

y_train_full = y[idx_train]
y_test = y[idx_test]

input_shape = X_train_full.shape[1:]   

input_shape = (input_shape[0], 1)[0]   
epoch_len = np.shape(X_zygo)[1]

# %%
# plotting sanity check 
idx = k
plot_random_epoch(features_all,subject=subj_test.iloc[idx],epoch=epoch_test.iloc[idx],nap_id=int(nap_test.iloc[idx]),random=False) # set random to false to input subject, nap and epoch you want to check

# %% [markdown]
# ### Calling function for training

# %%
epoch_num = 10 
num_classes = 2 # binary classification at each time step 
feature_num = 1
input_shape = 2248

# %%
tf.keras.backend.clear_session()

results_segmentation = run_kfold_training(
    model_func=unet_1d,
    X_train_full=X_train_full[:, :input_shape, :],
    X=X[:, :input_shape, :],
    y=to_one_hot(y[:, 0, :input_shape, np.newaxis]), # add one hot function when calling segmentation
    input_shape=input_shape, # to make divisible by 4 
    num_classes=num_classes,
    feature_num=feature_num,
    compile_kwargs={
        "optimizer": "adam",
        "loss": "categorical_crossentropy",# "binary_crossentropy" use for single neuron 
        "metrics": ["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
    },
    fit_kwargs={"epochs": 10},
    n_splits=5)
# Out:
# Fold: 1 =================================================================
# Epoch 1/10
# 286/286 [==============================] - 143s 395ms/step - loss: 0.2565 - accuracy: 0.9595 - precision: 0.9595 - recall: 0.9595 - val_loss: 0.1913 - val_accuracy: 0.9635 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 2/10
# 286/286 [==============================] - 147s 513ms/step - loss: 0.1832 - accuracy: 0.9626 - precision: 0.9626 - recall: 0.9626 - val_loss: 0.1744 - val_accuracy: 0.9635 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 3/10
# 286/286 [==============================] - 120s 420ms/step - loss: 0.1709 - accuracy: 0.9626 - precision: 0.9626 - recall: 0.9626 - val_loss: 0.1646 - val_accuracy: 0.9636 - val_precision: 0.9636 - val_recall: 0.9636
# Epoch 4/10
# 286/286 [==============================] - 112s 390ms/step - loss: 0.1654 - accuracy: 0.9627 - precision: 0.9627 - recall: 0.9627 - val_loss: 0.1622 - val_accuracy: 0.9635 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 5/10
# 286/286 [==============================] - 115s 401ms/step - loss: 0.1629 - accuracy: 0.9627 - precision: 0.9627 - recall: 0.9627 - val_loss: 0.1586 - val_accuracy: 0.9636 - val_precision: 0.9636 - val_recall: 0.9636
# Epoch 6/10
# 286/286 [==============================] - 118s 410ms/step - loss: 0.1612 - accuracy: 0.9627 - precision: 0.9627 - recall: 0.9627 - val_loss: 0.1579 - val_accuracy: 0.9636 - val_precision: 0.9636 - val_recall: 0.9636
# Epoch 7/10
# 286/286 [==============================] - 139s 484ms/step - loss: 0.1606 - accuracy: 0.9627 - precision: 0.9627 - recall: 0.9627 - val_loss: 0.1571 - val_accuracy: 0.9636 - val_precision: 0.9636 - val_recall: 0.9636
# Epoch 8/10
# 286/286 [==============================] - 110s 384ms/step - loss: 0.1601 - accuracy: 0.9627 - precision: 0.9627 - recall: 0.9627 - val_loss: 0.1568 - val_accuracy: 0.9636 - val_precision: 0.9636 - val_recall: 0.9636
# Epoch 9/10
# 286/286 [==============================] - 129s 450ms/step - loss: 0.1599 - accuracy: 0.9627 - precision: 0.9627 - recall: 0.9627 - val_loss: 0.1572 - val_accuracy: 0.9636 - val_precision: 0.9636 - val_recall: 0.9636
# Epoch 10/10
# 286/286 [==============================] - 115s 400ms/step - loss: 0.1599 - accuracy: 0.9627 - precision: 0.9627 - recall: 0.9627 - val_loss: 0.1562 - val_accuracy: 0.9636 - val_precision: 0.9636 - val_recall: 0.9636
# 72/72 [==============================] - 6s 82ms/step - loss: 0.1562 - accuracy: 0.9636 - precision: 0.9636 - recall: 0.9636
# Fold: 2 =================================================================
# Epoch 1/10
# 286/286 [==============================] - 145s 407ms/step - loss: 0.2480 - accuracy: 0.9600 - precision: 0.9607 - recall: 0.9607 - val_loss: 0.1864 - val_accuracy: 0.9630 - val_precision: 0.9630 - val_recall: 0.9630
# Epoch 2/10
# 286/286 [==============================] - 138s 481ms/step - loss: 0.1806 - accuracy: 0.9627 - precision: 0.9627 - recall: 0.9627 - val_loss: 0.1705 - val_accuracy: 0.9630 - val_precision: 0.9630 - val_recall: 0.9630
# Epoch 3/10
# 286/286 [==============================] - 131s 458ms/step - loss: 0.1686 - accuracy: 0.9628 - precision: 0.9628 - recall: 0.9628 - val_loss: 0.1642 - val_accuracy: 0.9629 - val_precision: 0.9629 - val_recall: 0.9629
# Epoch 4/10
# 286/286 [==============================] - 128s 447ms/step - loss: 0.1638 - accuracy: 0.9628 - precision: 0.9628 - recall: 0.9628 - val_loss: 0.1624 - val_accuracy: 0.9630 - val_precision: 0.9630 - val_recall: 0.9630
# Epoch 5/10
# 286/286 [==============================] - 126s 440ms/step - loss: 0.1618 - accuracy: 0.9628 - precision: 0.9628 - recall: 0.9628 - val_loss: 0.1595 - val_accuracy: 0.9630 - val_precision: 0.9630 - val_recall: 0.9630
# Epoch 6/10
# 286/286 [==============================] - 176s 613ms/step - loss: 0.1605 - accuracy: 0.9628 - precision: 0.9628 - recall: 0.9628 - val_loss: 0.1599 - val_accuracy: 0.9630 - val_precision: 0.9630 - val_recall: 0.9630
# Epoch 7/10
# 286/286 [==============================] - 136s 474ms/step - loss: 0.1599 - accuracy: 0.9628 - precision: 0.9628 - recall: 0.9628 - val_loss: 0.1587 - val_accuracy: 0.9630 - val_precision: 0.9630 - val_recall: 0.9630
# Epoch 8/10
# 286/286 [==============================] - 140s 490ms/step - loss: 0.1597 - accuracy: 0.9628 - precision: 0.9628 - recall: 0.9628 - val_loss: 0.1585 - val_accuracy: 0.9630 - val_precision: 0.9630 - val_recall: 0.9630
# Epoch 9/10
# 286/286 [==============================] - 159s 555ms/step - loss: 0.1594 - accuracy: 0.9628 - precision: 0.9628 - recall: 0.9628 - val_loss: 0.1583 - val_accuracy: 0.9630 - val_precision: 0.9630 - val_recall: 0.9630
# Epoch 10/10
# 286/286 [==============================] - 147s 515ms/step - loss: 0.1592 - accuracy: 0.9628 - precision: 0.9628 - recall: 0.9628 - val_loss: 0.1583 - val_accuracy: 0.9630 - val_precision: 0.9630 - val_recall: 0.9630
# 72/72 [==============================] - 7s 90ms/step - loss: 0.1583 - accuracy: 0.9630 - precision: 0.9630 - recall: 0.9630
# Fold: 3 =================================================================
# Epoch 1/10
# 286/286 [==============================] - 235s 696ms/step - loss: 0.2461 - accuracy: 0.9610 - precision: 0.9614 - recall: 0.9614 - val_loss: 0.1864 - val_accuracy: 0.9628 - val_precision: 0.9628 - val_recall: 0.9628
# Epoch 2/10
# 286/286 [==============================] - 174s 607ms/step - loss: 0.1790 - accuracy: 0.9627 - precision: 0.9627 - recall: 0.9627 - val_loss: 0.1714 - val_accuracy: 0.9628 - val_precision: 0.9628 - val_recall: 0.9628
# Epoch 3/10
# 286/286 [==============================] - 181s 632ms/step - loss: 0.1682 - accuracy: 0.9628 - precision: 0.9628 - recall: 0.9628 - val_loss: 0.1654 - val_accuracy: 0.9628 - val_precision: 0.9628 - val_recall: 0.9628
# Epoch 4/10
# 286/286 [==============================] - 188s 657ms/step - loss: 0.1635 - accuracy: 0.9628 - precision: 0.9628 - recall: 0.9628 - val_loss: 0.1617 - val_accuracy: 0.9628 - val_precision: 0.9628 - val_recall: 0.9628
# Epoch 5/10
# 286/286 [==============================] - 160s 558ms/step - loss: 0.1613 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - val_loss: 0.1616 - val_accuracy: 0.9626 - val_precision: 0.9626 - val_recall: 0.9626
# Epoch 6/10
# 286/286 [==============================] - 205s 716ms/step - loss: 0.1602 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - val_loss: 0.1611 - val_accuracy: 0.9628 - val_precision: 0.9628 - val_recall: 0.9628
# Epoch 7/10
# 286/286 [==============================] - 206s 721ms/step - loss: 0.1594 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - val_loss: 0.1605 - val_accuracy: 0.9628 - val_precision: 0.9628 - val_recall: 0.9628
# Epoch 8/10
# 286/286 [==============================] - 187s 653ms/step - loss: 0.1594 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - val_loss: 0.1595 - val_accuracy: 0.9628 - val_precision: 0.9628 - val_recall: 0.9628
# Epoch 9/10
# 286/286 [==============================] - 166s 582ms/step - loss: 0.1592 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - val_loss: 0.1620 - val_accuracy: 0.9628 - val_precision: 0.9628 - val_recall: 0.9628
# Epoch 10/10
# 286/286 [==============================] - 196s 685ms/step - loss: 0.1591 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - val_loss: 0.1590 - val_accuracy: 0.9628 - val_precision: 0.9628 - val_recall: 0.9628
# 72/72 [==============================] - 10s 136ms/step - loss: 0.1590 - accuracy: 0.9628 - precision: 0.9628 - recall: 0.9628
# Fold: 4 =================================================================
# Epoch 1/10
# 286/286 [==============================] - 285s 825ms/step - loss: 0.2576 - accuracy: 0.9594 - precision: 0.9601 - recall: 0.9601 - val_loss: 0.1872 - val_accuracy: 0.9627 - val_precision: 0.9627 - val_recall: 0.9627
# Epoch 2/10
# 286/286 [==============================] - 207s 721ms/step - loss: 0.1814 - accuracy: 0.9628 - precision: 0.9628 - recall: 0.9628 - val_loss: 0.1727 - val_accuracy: 0.9627 - val_precision: 0.9627 - val_recall: 0.9627
# Epoch 3/10
# 286/286 [==============================] - 276s 967ms/step - loss: 0.1696 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - val_loss: 0.1661 - val_accuracy: 0.9627 - val_precision: 0.9627 - val_recall: 0.9627
# Epoch 4/10
# 286/286 [==============================] - 200s 700ms/step - loss: 0.1645 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - val_loss: 0.1630 - val_accuracy: 0.9627 - val_precision: 0.9627 - val_recall: 0.9627
# Epoch 5/10
# 286/286 [==============================] - 223s 779ms/step - loss: 0.1618 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - val_loss: 0.1612 - val_accuracy: 0.9627 - val_precision: 0.9627 - val_recall: 0.9627
# Epoch 6/10
# 286/286 [==============================] - 187s 653ms/step - loss: 0.1607 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - val_loss: 0.1601 - val_accuracy: 0.9627 - val_precision: 0.9627 - val_recall: 0.9627
# Epoch 7/10
# 286/286 [==============================] - 212s 743ms/step - loss: 0.1598 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - val_loss: 0.1601 - val_accuracy: 0.9627 - val_precision: 0.9627 - val_recall: 0.9627
# Epoch 8/10
# 286/286 [==============================] - 251s 878ms/step - loss: 0.1593 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - val_loss: 0.1593 - val_accuracy: 0.9627 - val_precision: 0.9627 - val_recall: 0.9627
# Epoch 9/10
# 286/286 [==============================] - 237s 828ms/step - loss: 0.1593 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - val_loss: 0.1600 - val_accuracy: 0.9627 - val_precision: 0.9627 - val_recall: 0.9627
# Epoch 10/10
# 286/286 [==============================] - 231s 808ms/step - loss: 0.1590 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - val_loss: 0.1596 - val_accuracy: 0.9627 - val_precision: 0.9627 - val_recall: 0.9627
# 72/72 [==============================] - 9s 125ms/step - loss: 0.1596 - accuracy: 0.9627 - precision: 0.9627 - recall: 0.9627
# Fold: 5 =================================================================
# Epoch 1/10
# 286/286 [==============================] - 324s 990ms/step - loss: 0.2383 - accuracy: 0.9616 - precision: 0.9618 - recall: 0.9618 - val_loss: 0.1952 - val_accuracy: 0.9612 - val_precision: 0.9612 - val_recall: 0.9612
# Epoch 2/10
# 286/286 [==============================] - 264s 922ms/step - loss: 0.1743 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - val_loss: 0.1731 - val_accuracy: 0.9623 - val_precision: 0.9623 - val_recall: 0.9623
# Epoch 3/10
# 286/286 [==============================] - 255s 890ms/step - loss: 0.1657 - accuracy: 0.9630 - precision: 0.9630 - recall: 0.9630 - val_loss: 0.1651 - val_accuracy: 0.9623 - val_precision: 0.9623 - val_recall: 0.9623
# Epoch 4/10
# 286/286 [==============================] - 267s 935ms/step - loss: 0.1618 - accuracy: 0.9630 - precision: 0.9630 - recall: 0.9630 - val_loss: 0.1633 - val_accuracy: 0.9621 - val_precision: 0.9621 - val_recall: 0.9621
# Epoch 5/10
# 286/286 [==============================] - 469s 2s/step - loss: 0.1601 - accuracy: 0.9630 - precision: 0.9630 - recall: 0.9630 - val_loss: 0.1616 - val_accuracy: 0.9623 - val_precision: 0.9623 - val_recall: 0.9623
# Epoch 6/10
# 286/286 [==============================] - 277s 971ms/step - loss: 0.1595 - accuracy: 0.9630 - precision: 0.9630 - recall: 0.9630 - val_loss: 0.1613 - val_accuracy: 0.9623 - val_precision: 0.9623 - val_recall: 0.9623
# Epoch 7/10
# 286/286 [==============================] - 244s 850ms/step - loss: 0.1590 - accuracy: 0.9630 - precision: 0.9630 - recall: 0.9630 - val_loss: 0.1609 - val_accuracy: 0.9623 - val_precision: 0.9623 - val_recall: 0.9623
# Epoch 8/10
# 286/286 [==============================] - 247s 865ms/step - loss: 0.1588 - accuracy: 0.9630 - precision: 0.9630 - recall: 0.9630 - val_loss: 0.1633 - val_accuracy: 0.9623 - val_precision: 0.9623 - val_recall: 0.9623
# Epoch 9/10
# 286/286 [==============================] - 261s 911ms/step - loss: 0.1586 - accuracy: 0.9630 - precision: 0.9630 - recall: 0.9630 - val_loss: 0.1614 - val_accuracy: 0.9623 - val_precision: 0.9623 - val_recall: 0.9623
# Epoch 10/10
# 286/286 [==============================] - 236s 824ms/step - loss: 0.1585 - accuracy: 0.9630 - precision: 0.9630 - recall: 0.9630 - val_loss: 0.1607 - val_accuracy: 0.9623 - val_precision: 0.9623 - val_recall: 0.9623
# 72/72 [==============================] - 13s 180ms/step - loss: 0.1607 - accuracy: 0.9623 - precision: 0.9623 - recall: 0.9623
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 26
#       9 results_segmentation = run_kfold_training(
#      10     model_func=unet_1d,
#      11     X_train_full=X_train_full[:, :input_shape, :],
#    (...)
#      22     fit_kwargs={"epochs": 10},
#      23     n_splits=5)
#      25 model_segmentation = results_segmentation["models"][-1]
# ---> 26 model_history_segmentation = model_segmentation.fit(X_train_full[:, :input_shape, :], y_train_full[:, 0, :input_shape, np.newaxis], epochs=epoch_num, validation_data=(np.array(X_test[:, :2248, :], dtype=np.float32), np.array(y_test[:, 0, :2248, np.newaxis], dtype=np.float32))) #, callbacks=[early_stop])
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /var/folders/vy/grssbq395j340gpb616mgthm0000gn/T/__autograph_generated_fileh4xwr_31.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "/Users/zeynepozkaya/anaconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/src/engine/training.py", line 1401, in train_function  *
#         return step_function(self, iterator)
#     File "/Users/zeynepozkaya/anaconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/src/engine/training.py", line 1384, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Users/zeynepozkaya/anaconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/src/engine/training.py", line 1373, in run_step  **
#         outputs = model.train_step(data)
#     File "/Users/zeynepozkaya/anaconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/src/engine/training.py", line 1151, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/Users/zeynepozkaya/anaconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/src/engine/training.py", line 1209, in compute_loss
#         return self.compiled_loss(
#     File "/Users/zeynepozkaya/anaconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/src/engine/compile_utils.py", line 277, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/Users/zeynepozkaya/anaconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/src/losses.py", line 143, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/Users/zeynepozkaya/anaconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/src/losses.py", line 270, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/Users/zeynepozkaya/anaconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/src/losses.py", line 2221, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "/Users/zeynepozkaya/anaconda3/envs/tf_gpu/lib/python3.10/site-packages/keras/src/backend.py", line 5573, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (32, 2248, 1) and (32, 2248, 2) are incompatible

# %%
model_segmentation = results_segmentation["models"][-1]
model_history_segmentation = model_segmentation.fit(X_train_full[:, :input_shape, :], to_one_hot(y_train_full[:, 0, :input_shape, np.newaxis]), epochs=epoch_num, validation_data=(np.array(X_test[:, :2248, :], dtype=np.float32), to_one_hot(np.array(y_test[:, 0, :2248, np.newaxis], dtype=np.float32)))) #, callbacks=[early_stop])
# Out:
# Epoch 1/10
# 2026-05-29 00:42:02.129419: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 357/357 [==============================] - 158s 396ms/step - loss: 0.0955 - accuracy: 0.9714 - precision: 0.9714 - recall: 0.9714 - val_loss: 0.0952 - val_accuracy: 0.9718 - val_precision: 0.9718 - val_recall: 0.9718
# Epoch 2/10
# 357/357 [==============================] - 22243s 62s/step - loss: 0.0903 - accuracy: 0.9725 - precision: 0.9725 - recall: 0.9725 - val_loss: 0.0872 - val_accuracy: 0.9733 - val_precision: 0.9733 - val_recall: 0.9733
# Epoch 3/10
# 357/357 [==============================] - 126s 353ms/step - loss: 0.0896 - accuracy: 0.9726 - precision: 0.9726 - recall: 0.9726 - val_loss: 0.0877 - val_accuracy: 0.9729 - val_precision: 0.9729 - val_recall: 0.9729
# Epoch 4/10
# 357/357 [==============================] - 195s 546ms/step - loss: 0.0877 - accuracy: 0.9729 - precision: 0.9729 - recall: 0.9729 - val_loss: 0.0869 - val_accuracy: 0.9736 - val_precision: 0.9736 - val_recall: 0.9736
# Epoch 5/10
# 357/357 [==============================] - 121s 337ms/step - loss: 0.0875 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - val_loss: 0.0896 - val_accuracy: 0.9721 - val_precision: 0.9721 - val_recall: 0.9721
# Epoch 6/10
# 357/357 [==============================] - 243s 680ms/step - loss: 0.0871 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - val_loss: 0.0971 - val_accuracy: 0.9717 - val_precision: 0.9717 - val_recall: 0.9717
# Epoch 7/10
# 357/357 [==============================] - 114s 318ms/step - loss: 0.0868 - accuracy: 0.9732 - precision: 0.9732 - recall: 0.9732 - val_loss: 0.0915 - val_accuracy: 0.9721 - val_precision: 0.9721 - val_recall: 0.9721
# Epoch 8/10
# 357/357 [==============================] - 218s 610ms/step - loss: 0.0862 - accuracy: 0.9735 - precision: 0.9735 - recall: 0.9735 - val_loss: 0.0982 - val_accuracy: 0.9700 - val_precision: 0.9700 - val_recall: 0.9700
# Epoch 9/10
# 357/357 [==============================] - 412s 1s/step - loss: 0.0861 - accuracy: 0.9733 - precision: 0.9733 - recall: 0.9733 - val_loss: 0.0918 - val_accuracy: 0.9716 - val_precision: 0.9716 - val_recall: 0.9716
# Epoch 10/10
# 357/357 [==============================] - 127s 354ms/step - loss: 0.0862 - accuracy: 0.9733 - precision: 0.9733 - recall: 0.9733 - val_loss: 0.0910 - val_accuracy: 0.9724 - val_precision: 0.9724 - val_recall: 0.9724

# %%
import pickle

# Save
with open('model_segmentation_2neuronn_2905.pkl', 'wb') as f:
    pickle.dump(model_segmentation, f)

# %% [markdown]
# ## Results and Testing

# %% [markdown]
# ### K-means Results

# %% [markdown]
# Loading in pre-trained model s

# %%
with open("model_segmentation_v2.pkl", "rb") as f:
    model_segmentation = pickle.load(f)

# %%
with open("model_segmentation_2neuronn.pkl", "rb") as f:
    model_segmentation_2n = pickle.load(f)

# %%
cvScores = results_segmentation["cv_scores"]
for metric in ['accuracy', 'loss']:
    vals = [s[metric] for s in cvScores]
    print(f"{metric}: {np.mean(vals):.4f} ± {np.std(vals):.4f}")
# Out:
# accuracy: 0.9629 ± 0.0004
# loss: 0.1588 ± 0.0015

# %% [markdown]
# ### Testing - Accuracy and F1

# %%
input_shape = 2248
y_pred_train_2n = model_segmentation_2n.predict(X_train_full[:, :input_shape, :])  
y_pred_test_2n = model_segmentation_2n.predict(np.array(X_test[:, :input_shape, :], dtype=np.float32))  

y_pred_train_labels = np.argmax(y_pred_train_2n, axis=-1, keepdims=True)  # (14280, 2248, 1)
y_pred_test_labels  = np.argmax(y_pred_test_2n,  axis=-1, keepdims=True)  
#print(iou_metric(y_true, y_pred_train, threshold=0.5))
#print(iou_metric(y_true, y_pred_test, threshold=0.5))
# Out:
# 357/357 [==============================] - 25s 65ms/step
# 90/90 [==============================] - 8s 72ms/step

# %%
input_shape = 2248
y_pred_train = model_segmentation.predict(X_train_full[:, :input_shape, :])  
y_pred_test = model_segmentation.predict(np.array(X_test[:, :input_shape, :], dtype=np.float32))  

y_pred_train_thr = convert_to_binary(y_pred_train,thr=.5)
y_pred_test_thr = convert_to_binary(y_pred_test,thr=.5)

#y_pred_train_labels = np.argmax(y_pred_train, axis=-1, keepdims=True)  # (14280, 2248, 1)
#y_pred_test_labels  = np.argmax(y_pred_test,  axis=-1, keepdims=True)  
#print(iou_metric(y_true, y_pred_train, threshold=0.5))
#print(iou_metric(y_true, y_pred_test, threshold=0.5))
# Out:
# 357/357 [==============================] - 29s 75ms/step
# 90/90 [==============================] - 10s 76ms/step

# %% [markdown]
# ## Plotting

# %%
i = random.randint(0, np.shape(y_pred_train_labels)[0])
k = random.randint(0, 2856)

'''
b = plt.plot(y_train_full[:,0][:,:input_shape][i,:],label="labels")
a = plt.plot(y_pred_train.squeeze()[i,:],label="prediction training")
plt.ylim(0,1)
plt.legend()
plt.show()
''' 
y_true = y_pred_test_labels.squeeze()[k,:].copy()
#y_true = (y_true > 0.6).astype(int)
#y_true = uniform_filter1d(y_true, size=20)  
#d = plt.plot(X_test[k,:input_shape,:].squeeze(),label="contraction")


fig, axs = plt.subplots(
    nrows=2,
    ncols=2,
    figsize=(12, 6),
    gridspec_kw={'width_ratios': [3, 1]}  # optional
)

# Existing plots
axs[0, 0].plot(y_true,color="orange",label="prediction testing")
axs[0, 0].set_title("Testing")

axs[1, 0].plot(y_test[:,0][:,:input_shape][k,:],label="labels")
axs[1, 0].set_title("Labels")

# New subplot on the right
axs[0, 1].plot(y_pred_test.squeeze()[k,:].copy(),color="orange",label="prediction testing")
axs[0,1].plot(y_test[:,0][:,:input_shape][k,:],label="labels")
axs[0, 1].set_title("Third Plot")
axs[0, 1].set_title("Raw output with one neuron")

#axs[1, 1].plot(y_pred_test.squeeze()[k,:].copy(),color="orange",label="prediction testing")
axs[1,1].plot(X_test[k,:,:],label="labels")
axs[1, 1].set_title("Time series")

# Optionally leave bottom-right empty

fig.suptitle(f"Subject: {subject[idx_test].iloc[k]}, Nap: {np.array(nap)[idx_test][k]}, Epoch: {np.array(epoch)[idx_test][k]}, Index: {k}", fontsize=16)
fig.tight_layout(rect=[0, 0, 1, 0.93])

plt.show()

#b = plt.plot(y_test[:,0][:,:input_shape][k,:],label="labels")
#c = plt.plot(y_true,label="prediction testing")

# %%
plot_random_epoch(features_all,subject=subj_test.iloc[k],epoch=epoch_test.iloc[k],nap_id=int(nap_test.iloc[k]),random=False) # set random to false to input subject, nap and epoch you want to check

# %%
with open('model_segmentation.pickle', 'wb') as handle:
    pickle.dump(model_segmentation, handle)

# %% [markdown]
# ## Model Performance Functions

# %%
def get_impulses(x):
    """
    Convert binary signal into list of (start, end) impulses.
    """
    x = np.asarray(x).astype(int)

    starts = np.where(np.diff(np.r_[0, x]) == 1)[0]
    ends   = np.where(np.diff(np.r_[x, 0]) == -1)[0]

    return list(zip(starts, ends))


def impulse_count_metrics(y_true, y_pred, min_len=1):
    """
    Count impulses in binary sequences and compare counts.
    """
    true_impulses = get_impulses(y_true)
    pred_impulses = get_impulses(y_pred)

    true_count = len([imp for imp in true_impulses if (imp[1] - imp[0]) >= min_len])
    pred_count = len([imp for imp in pred_impulses if (imp[1] - imp[0]) >= min_len])

    count_error = pred_count - true_count
    abs_count_error = abs(count_error)

    return {
        "true_count": true_count,
        "pred_count": pred_count,
        "count_error": count_error,          # positive = over-prediction
        "abs_count_error": abs_count_error,  # smaller is better
        "exact_count_match": int(pred_count == true_count),
    }

def evaluate_impulses(y_true, y_pred, onset_tolerance=25):
    """
    Compare impulse onsets and durations.

    Parameters
    ----------
    y_true : (T,)
    y_pred : (T,)
    onset_tolerance : int
        Maximum onset difference (samples) for a match.

    Returns
    -------
    dict
    """

    true_impulses = get_impulses(y_true)
    pred_impulses = get_impulses(y_pred)

    matched_pred = set()

    onset_errors = []
    duration_errors = []

    TP = 0

    for t_start, t_end in true_impulses:

        best_match = None
        best_error = np.inf

        for j, (p_start, p_end) in enumerate(pred_impulses):

            if j in matched_pred:
                continue

            onset_error = abs(p_start - t_start)

            if onset_error <= onset_tolerance and onset_error < best_error:
                best_error = onset_error
                best_match = j

        if best_match is not None:

            matched_pred.add(best_match)

            p_start, p_end = pred_impulses[best_match]

            TP += 1

            onset_errors.append(p_start - t_start)

            true_duration = t_end - t_start
            pred_duration = p_end - p_start

            duration_errors.append(pred_duration - true_duration)

    FN = len(true_impulses) - TP
    FP = len(pred_impulses) - TP

    precision = TP / (TP + FP) if (TP + FP) else 0
    recall = TP / (TP + FN) if (TP + FN) else 0

    f1 = (
        2 * precision * recall / (precision + recall)
        if (precision + recall)
        else 0
    )

    return {
        "true_impulses": len(true_impulses),
        "pred_impulses": len(pred_impulses),
        "TP": TP,
        "FP": FP,
        "FN": FN,
        "precision": precision,
        "recall": recall,
        "f1": f1,
        "mean_onset_error": np.mean(onset_errors) if onset_errors else np.nan,
        "mean_abs_onset_error": np.mean(np.abs(onset_errors)) if onset_errors else np.nan,
        "mean_duration_error": np.mean(duration_errors) if duration_errors else np.nan,
        "mean_abs_duration_error": np.mean(np.abs(duration_errors)) if duration_errors else np.nan,
    }

# %% [markdown]
# ## Display metrics

# %% [markdown]
# ### 2 Neuron

# %%
all_metrics = []

for k in range(len(y_pred_test_labels)):

    m = evaluate_impulses(
        y_test[k, 0, :2248],
        y_pred_test_labels[k, :, 0],
        onset_tolerance=20
    )

    all_metrics.append(m)

print("Mean F1:",
      np.mean([m["f1"] for m in all_metrics]))

print("Mean onset error:",
      np.nanmean([m["mean_abs_onset_error"] for m in all_metrics]))

print("Mean duration error:",
      np.nanmean([m["mean_abs_duration_error"] for m in all_metrics]))
# Out:
# Mean F1: 0.04503384089596578
# Mean onset error: 12.65328846742123
# Mean duration error: 36.9361586961694

# %%
count_results = []

for k in range(len(y_pred_test_labels)):
    m = impulse_count_metrics(
        y_test[k, 0, :2248],
        y_pred_test_labels[k, :, 0]
    )
    count_results.append(m)

mean_abs_count_error = np.mean([r["abs_count_error"] for r in count_results])
count_match_rate = np.mean([r["exact_count_match"] for r in count_results])

print("Mean absolute count error:", mean_abs_count_error)
print("Exact count match rate:", count_match_rate)
# Out:
# Mean absolute count error: 0.7727591036414566
# Exact count match rate: 0.7391456582633054

# %% [markdown]
# ### One neuron

# %%
y_pred_train_thr = convert_to_binary(y_pred_train,thr=.5)
y_pred_test_thr = convert_to_binary(y_pred_test,thr=.5)

# %%
all_metrics = []

for k in range(len(y_pred_test)):

    m = evaluate_impulses(
        y_test[k, 0, :2248],
        y_pred_test_thr[k],
        onset_tolerance=20
    )

    all_metrics.append(m)

print("Mean F1:",
      np.mean([m["f1"] for m in all_metrics]))

print("Mean onset error:",
      np.nanmean([m["mean_abs_onset_error"] for m in all_metrics]))

print("Mean duration error:",
      np.nanmean([m["mean_abs_duration_error"] for m in all_metrics]))
# Out:
# Mean F1: 0.05732274806763614
# Mean onset error: 11.805898746576712
# Mean duration error: 35.00836380087792

# %%
count_results = []

for k in range(len(y_pred_test)):
    m = impulse_count_metrics(
        y_test[k, 0, :2248],
        y_pred_test_thr[k]
    )
    count_results.append(m)

mean_abs_count_error = np.mean([r["abs_count_error"] for r in count_results])
count_match_rate = np.mean([r["exact_count_match"] for r in count_results])

print("Mean absolute count error:", mean_abs_count_error)
print("Exact count match rate:", count_match_rate)
# Out:
# Mean absolute count error: 0.9761904761904762
# Exact count match rate: 0.7219887955182073

# %% [markdown]
# ## Bad Code?

# %%
corr_mask = muscle_test == "Corr"
zygo_mask = muscle_test == "Zygo"

corr_mask_tr = muscle_train == "Corr"
zygo_mask_tr = muscle_train == "Zygo"

# full train

y_pred_train = model_segmentation.predict(X_train_full[:, :input_shape, :])  
y_pred_test = model_segmentation.predict(np.array(X_test[:, :2248, :], dtype=np.float32))  
 
# Calculate accuracy
accuracy_training = accuracy_score(y_train_full[:,0][:,:input_shape], y_pred_train)   
accuracy_tes = accuracy_score(y_test[:,0], y_pred_train)  

accuracy_training_zygo = accuracy_score(y_train_full[:,0][:,:input_shape][zygo_mask_tr], y_pred_train[zygo_mask_tr])   
accuracy_test_zygo = accuracy_score(y_test[:,0][:,:input_shape][zygo_mask], y_pred_train[zygo_mask])  

accuracy_training_corr = accuracy_score(y_train_full[:,0][:,:input_shape][corr_mask_tr], y_pred_train[corr_mask_tr])   
accuracy_test_corr = accuracy_score(y_test[:,0][:,:input_shape][corr_mask], y_pred_train[corr_mask] ) 

# Calculate F1 score
f1_training = f1_score(y_train_full[:,0][:,:input_shape], y_pred_train, average='weighted')  
f1_test = f1_score(y_test[:,0][:,:input_shape], y_pred_train, average='weighted')  

f1_training_zygo = f1_score(y_train_full[:,0][:,:input_shape][zygo_mask_tr], y_pred_train[zygo_mask_tr], average='weighted')   
f1_test_zygo = f1_score(y_test[:,0][:,:input_shape][zygo_mask], y_pred_train[zygo_mask], average='weighted')  

f1_training_corr = f1_score(y_train_full[:,0][:,:input_shape][corr_mask_tr], y_pred_train[corr_mask_tr], average='weighted')   
f1_test_corr = f1_score(y_test[:,0][[:,:input_shape]corr_mask], y_pred_train[corr_mask], average='weighted') 


# Print accuracy and F1 score
print("Corru Scores------------------------------")  
print("Training Accuracy :", accuracy_training_corr) 
print("Test Accuracy :", accuracy_test_corr)  
print("Training F1 Score :", f1_training_corr)  
print("Test F1 Score :", f1_test_corr) 

print("Zygo Scores------------------------------")  
print("Training Accuracy :", accuracy_training_zygo)  
print("Test Accuracy :", accuracy_test_zygo)  
print("Training F1 Score :", f1_training_zygo)   
print("Test F1 Score :", f1_test_zygo)

# %% [markdown]
# ### Plotting

# %%
# one plot demonstrating labels against data 
# one plot showing calculated values against data
