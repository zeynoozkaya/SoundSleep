# %% [markdown]
# ### Script for extracting contraction durations from sleep trials
#
# Will extract contraction information abd update trial information documents and dfs

# %%
from scipy.io import loadmat

# %%
data = loadmat('BIG_DATA_Basak_Este.mat')
# Out:
# /Users/zeynepozkaya/anaconda3/lib/python3.11/site-packages/scipy/io/matlab/_mio.py:227: MatReadWarning: Duplicate variable name "None" in stream - replacing previous with new
# Consider mio5.varmats_from_mat to split file into single variable files
#   matfile_dict = MR.get_variables(variable_names)

# %%
print(data.keys())
x = data['None']
print(x)
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'None', '__function_workspace__'])
# [(b'DATANap', b'MCOS', b'table', array([[3707764736],
#         [         2],
#         [         1],
#         [         1],
#         [         3],
#         [         2]], dtype=uint32))                ]
